# %% [markdown]
# ## 1. What are the key tasks that machine learning entails? What does data pre-processing imply?

# %% [markdown]
# ### **In machine learning the key tasks are:**
#
# * Regression
# * Classification
# * Transcription
# * Machine translation
# * Anomaly detection
# * Synthesis and sampling
# * Estimation of probability density and probability mass function etc.
#
# ### **In data pre-processing:**
#
# **Data Preprocessing:** Before starting training the models, it is of utmost importance to prepare data appropriately. As part of data preprocessing, some of the following is done:
#
# * Data cleaning: Data cleaning requires one to identify attributes having not enough data or attributes which are not have variance. These data (rows and columns) need to be removed from the training data set.
#
# * Missing data imputation: Handling missing data using data imputation techniques such as replacing missing data with mean, median, or mode.

# %% [markdown]
# ## 2. Describe quantitative and qualitative data in depth. Make a distinction between the two.

# %% [markdown]
# Data plays an important role as it the base for solving any time of problem. It is always necessary to investigate data as what is the type of the data and how we should proceed with it. As qualitative and quantitative data are concerned, they both are different.
#
# **Qualitative data:**
#
# 1. Qualitative data uses methods like interviews, participant observation, focus on a grouping to gain collective information.
#
# 2. Data format used in it is textual. Datasheets are contained of audio or video recordings and notes.
#
# 3. Qualitative data talks about the experience or quality and explains the questions like 'why' and 'how'.
#
# 4. The data is analyzed by grouping it into different categories.
#
# Example: What is the main activity of the farm? = Dairy, Do you work full time or part time? = Full, What is your occupation? = Deep Learning Developer, etc. This data is categorical in nature.
#
# ![Qualitative data](https://www.abs.gov.au/websitedbs/d3310114.nsf/0/8f239d2a50bee382ca25860e000b8c68/Body/0.30AC!OpenElement&FieldElemFormat=gif)
#
#
# **Quantitatative data:**
#
# 1. Quantitative data uses methods as questionnaires, surveys, and structural observations to gain collective information.
#
# 2. Data format used in it is numerical. Datasheets are obtained in the form of numerical values.
#
# 3. Quantitative data talks about the quantity and explains the questions like 'how much', 'how many'.
#
# 4. The data is analyzed by statistical methods.
#
# 5. Quantitative data are fixed and universal.
#
# Example: Suppose there is A person, we could ask him, How many children do you have? = 4 children, How many hours do you work? = 38 hours per week, How much do you earn? = $60,000 p.a.......... so, all these answers come under quantitative data. All the data mostly is numeric in nature.
#
# ![Qualitative data](https://www.abs.gov.au/websitedbs/d3310114.nsf/0/8f239d2a50bee382ca25860e000b8c68/Body/0.1A42!OpenElement&FieldElemFormat=gif)

# %% [markdown]
# ## 3. Create a basic data collection that includes some sample records. Have at least one attribute from each of the machine learning data types.

# %%
import pandas as pd

# %%
pd.read_csv("day.csv") ## This is a univariate Regression problem based for year
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
pd.read_csv("hour.csv") ## This is a univariate Regression problem based on per hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
pd.read_csv("abalone.data") ## This is a multivariate classification problem
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
pd.read_csv("proyecto/D_dribble1.txt", delimiter = "\t") ## text data problem
# Out:
#                          Keuwl Accelerometer Data File
# 0                                  2019-06-26 17-08-48
# 1    Time (s), X (m/s2), Y (m/s2), Z (m/s2), R (m/s...
# 2    0.0000000,3.428497,9.112331,-2.047042,9.948847...
# 3    0.0097030,3.447650,9.285912,-2.331953,10.17607...
# 4    0.0197340,3.506308,9.212888,-2.244564,10.10987...
# ..                                                 ...
# 986  9.8799067,3.989937,8.725668,-0.760159,9.624694...
# 987  9.8899698,4.096479,8.585608,-0.766145,9.543624...
# 988  9.9006042,4.034230,8.754398,-0.822408,9.674236...
# 989  9.9104309,3.951630,9.159019,-1.513135,10.08923...
# 990  9.9197140,3.681085,9.283517,-2.084153,10.20185...
#
# [991 rows x 1 columns]

# %%
pd.read_excel("Extra files/Dress Sales.xlsx") ## Time series data problem
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %% [markdown]
# **So, here we collected the sample data of machine learning data attributes like Classification, Regression, Uni-variate, Bi-variate, Text data, Time-series data etc.**

# %% [markdown]
# ## 4. What are the various causes of machine learning data issues? What are the ramifications?

# %% [markdown]
# In machine learning data issues causes a developer to struggle really hard. In ML or deep learning, data is the utmost important part on which the whole ecosystem of the AI depends. Some issues regarding the data which can arise are as follows:
#
# * Inadequate Training data:
#     * Noisy Data- It is responsible for an inaccurate prediction that affects the decision as well as accuracy in classification tasks.
#     * Incorrect data- It is also responsible for faulty programming and results obtained in machine learning models. Hence, incorrect data may affect the accuracy of the results also.
#     * Generalizing of output data- Sometimes, it is also found that generalizing output data becomes complex, which results in comparatively poor future actions.
#
# * Poor quality of data:
# As Noisy data, Incorrect dat, Generalizing of output data causes issues, same is the case of poor quality of data, it means we train our model with poor data which is not that much related with our problem statement and it generates poor results as well.
#
# * Non-representative training data:
# Further, if we are using non-representative training data in the model, it results in less accurate predictions. A machine learning model is said to be ideal if it predicts well for generalized cases and provides accurate decisions. If there is less training data, then there will be a sampling noise in the model, called the non-representative training set. It won't be accurate in predictions. To overcome this, it will be biased against one class or a group.
#
# * Overfitting and Underfitting:
# Overfitting is one of the most common issues faced by Machine Learning engineers and data scientists. Whenever a machine learning model is trained with a huge amount of data, it starts capturing noise and inaccurate data into the training data set. It negatively affects the performance of the model.
#
# **Methods to reduce overfitting:**
#
# * Increase training data in a dataset.
# * Reduce model complexity by simplifying the model by selecting one with fewer parameters
# * Ridge Regularization and Lasso Regularization
# * Early stopping during the training phase
# * Reduce the noise
# * Reduce the number of attributes in training data.
# * Constraining the model.
#
#
# Underfitting is just the opposite of overfitting. Whenever a machine learning model is trained with fewer amounts of data, and as a result, it provides incomplete and inaccurate data and destroys the accuracy of the machine learning model.
#
# **Methods to reduce Underfitting:**
#
# * Increase model complexity
# * Remove noise from the data
# * Trained on increased and better features
# * Reduce the constraints
# * Increase the number of epochs to get better results.
#
# * Data Bias:
# Data Biasing is also found a big challenge in Machine Learning. These errors exist when certain elements of the dataset are heavily weighted or need more importance than others. Biased data leads to inaccurate results, skewed outcomes, and other analytical errors. However, we can resolve this error by determining where data is actually biased in the dataset. Further, take necessary steps to reduce it.
#
# **Methods to remove Data Bias:**
#
# * Research more for customer segmentation.
# * Be aware of your general use cases and potential outliers.
# * Combine inputs from multiple sources to ensure data diversity.
# * Include bias testing in the development process.
# * Analyze data regularly and keep tracking errors to resolve them easily.
# * Review the collected and annotated data.
# * Use multi-pass annotation such as sentiment analysis, content moderation, and intent recognition.

# %% [markdown]
# ## 5. Demonstrate various approaches to categorical data exploration with appropriate examples.

# %% [markdown]
# While most machine learning algorithms only work with numeric values, many important real-world features are not numeric but rather categorical. As categorical features, they take on levels or values. These can be represented as various categories such as age, state, or customer type for example. Alternatively, these can be created by binning underlying numeric features, such as identifying individuals by age ranges (e.g., 0–10, 11–18, 19–30, 30–50, etc.). Finally, these can be numeric identifiers where the relationship between the values is not meaningful. ZIP codes are a common example of this. Two ZIP codes close numerically may be farther apart than another ZIP code that is distant numerically.
#
# A useful way to summarize two categorical variables is a contigency table- `a table of counts by category, a bar graph, a pie chart, box plot, violon plot etc.`
#
# ![categorical pathway](https://www.kdnuggets.com/wp-content/uploads/garg_cat_variables_15.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/gedeck/practical-statistics-for-data-scientists/master/data/lc_loans.csv")
data.head()
# Out:
#         status grade
# 0   Fully Paid     B
# 1  Charged Off     C
# 2   Fully Paid     C
# 3   Fully Paid     C
# 4      Current     B

# %%
data.status.value_counts()
# Out:
# Current        321185
# Fully Paid      97316
# Charged Off     22671
# Late             9789
# Name: status, dtype: int64

# %%
## contigency table
crosstab = data.pivot_table(index = 'grade', columns = 'status', aggfunc = lambda x: len(x), margins = True)
df = crosstab.loc['A':'G', :].copy()
df.loc[:, 'Charged Off': 'Late'] = df.loc[:, 'Charged Off': 'Late'].div(df['All'], axis = 0)
df['All'] = df['All'] / sum(df['All'])
perc_crosstab = df
perc_crosstab
# Out:
# status  Charged Off   Current  Fully Paid      Late       All
# grade
# A          0.021548  0.690454    0.281528  0.006470  0.160746
# B          0.040054  0.709013    0.235401  0.015532  0.293529
# C          0.049828  0.735702    0.191495  0.022974  0.268039
# D          0.067410  0.717328    0.184189  0.031073  0.164708
# E          0.081657  0.707936    0.170929  0.039478  0.077177
# F          0.118258  0.654371    0.180409  0.046962  0.028614
# G          0.126196  0.614008    0.198396  0.061401  0.007187

# %%
label = ['Car', 'Bike', 'Truck', 'Cycle', 'Jeeps', 'Amulance']
no_vehicle = [941, 854, 4595, 2125, 942, 509]

# %%
index = np.arange(len(label))
  
print ("Total Labels : ", len(label))
print ("Indexing : ", index)
# Out:
# Total Labels :  6
# Indexing :  [0 1 2 3 4 5]

# %%
plt.bar(index, no_vehicle)
plt.xlabel('Type', fontsize = 15)
plt.ylabel('No of Vehicles', fontsize = 15)
plt.xticks(index, label, fontsize = 10, rotation = 30)
plt.title('Market Share for Each Genre 1995-2017')
  
plt.show()

# %%
plt.figure(figsize =(8, 8))
plt.pie(no_vehicle, labels = label, 
        startangle = 90, autopct ='%.1f %%')
plt.show()

# %% [markdown]
# ## 6. How would the learning activity be affected if certain variables have missing values? Having said that, what can be done about it?

# %% [markdown]
# It is not uncommon in the real-world applications for our training examples to be missing one or more values for various reasons. There could have been an error in the datacollection process, certain measurements may not be applicable, or particular fields could have been simply left blank in a survey. We typically see missing values as blank spaces in our data table or as placeholder strings such as NaN, which stands for "not a number", or NULL (a commonly used indicator of unknown values in relational databases). Unfortunately, most computational tools are unable to handle such missing values or will produce unpredictable results if we simply ignore them. Therefore, it is crucial in a ML learning process that we take care of those missing values before we proceed with further analyses.
#
# There are certain ways by which we can address this problem. generally we can:
#
# * identify the missing values first of all
# * Then we could eliminate training examples or features with missing values (not a good approach as we may loose some important information).
# * Imputing missing values:
#     * Mean imputation is one of the most common interpolation technique, where we simply replace the missing value with the mean value of the entire feature column.
#     * Another option is median or most_frequent, where the latter replaces the missing values with the most frequent values. This is useful for imputing categorical feature values, e.g., a feature column that stores an encoding of color names, such as red, green and blue.
#     * Also we have to handle Categorical data as well by looking if the data is nominal or ordinal and then using One Hot Encoding or some other techniques.

# %% [markdown]
# ## 7. Describe the various methods for dealing with missing data values in depth.

# %% [markdown]
# There are certain ways by which we can address this problem. generally we can:
#
# * identify the missing values first of all
# * Then we could eliminate training examples or features with missing values (not a good approach as we may loose some important information).
# * Imputing missing values:
#     * Mean imputation is one of the most common interpolation technique, where we simply replace the missing value with the mean value of the entire feature column.
#     * Another option is median or most_frequent, where the latter replaces the missing values with the most frequent values. This is useful for imputing categorical feature values, e.g., a feature column that stores an encoding of color names, such as red, green and blue.
#     * Also we have to handle Categorical data as well by looking if the data is nominal or ordinal and then using One Hot Encoding or some other techniques.
#
#
# **Suppose we have missing values in tabular data**
#
# Then the first task is to select and separate the numerical and categorical features and handle them one by one.
# In python - use `dataframe_name.isnull().sum()`, and we will get the count of missing values per column.
#
# **Take the numerical features first:**
#
#     * So, as we already discussed that One of the easiest ways to deal with missing data is simply to remove the corresponding features (columns) or training examples (rows) from the dataset entirely; rows with missing values can easily be dropped via the `dropna` method:
#
# $DataframeName.dropna(axis = 0)$
#
# Similarly, we can drop columns that have at least one NaN in any row by setting the axis argument to 1:
#
# $DataFrameName.dropna(axis=1)$
#
#     * We can also use imputation techniques:
#     For mean imputation, if the data not having any outlier issue, then we can **SimpleImputer** for doing imputation for mean, for outliers issues we will use median and for the categorical issues we will use mode.
# $SimpleImputer(missingValues = numpy.nan, strategy = \ 'mean')$
#
# $SimpleImputer(missingValues = numpy.nan, strategy = \ 'median')$
#
# $SimpleImputer(missingValues = numpy.nan, strategy =  \ 'mode')$

# %% [markdown]
# ## 8. What are the various data pre-processing techniques? Explain dimensionality reduction and function selection in a few words.

# %% [markdown]
# In **`Pre-Processing`** includes:
# * missing value - we can use mean, median and mode techniques etc.
# * outliers - boxplot, scatterplot etc.
# * scaling of the data - we can use standard scaler, min-max scaler etc.
# * encoding of the data - One Hot Encoding, IFD etc.
# * Feature selection - KNN, LASSO etc
# * Feature transformation - SimpleImputer, Standardscaler etc.
# * Feature merging - on the basis of multi-colinearity etc.
# * imbalanced data handling - Threshold Moving, Resampling etc.
#
#
# * Feature selection selects subset out of the total features.
#
# ![Feature slection](https://www.analyticsvidhya.com/wp-content/uploads/2016/11/FS1.png)
#
#     * It enables the machine learning algorithm to train faster.
#     * It reduces the complexity of a model and makes it easier to interpret.
#     * It improves the accuracy of a model if the right subset is chosen.
#     * It reduces overfitting.
#
# * Dimensionality reduction uses PCA for feature transfomation without neglecting some features as in simple feature selection. In the context of dimensionality reduction, feature extraction can be understood as an approach to data compression with the goal of maintaining most of the relevant information.
#
#     * It enables the machine learning models to work better than simple feature selected model.
#     * It helps in feature extraction even from a non regularized model.
#     * It helps in reducing the curse of dimensionality.
#     * It increases the predictive performance of the model.
#     * It also helps in optimizing storage space and computational efficiency.

# %% [markdown]
# ## 9.
#     i. What is the IQR? What criteria are used to assess it?
#     ii. Describe the various components of a box plot in detail? When will the lower whisker    surpass the upper whisker in length? How can box plots be used to identify outliers?

# %% [markdown]
# ### **I) IQR**:
#
# IQR stands for interquartile range, which generally tells us about the spread of the data about the median. The first quartile and the third quartile criteria is used to access it.
#
# ## **ii) Components of a box plot:**
#
# There are five components in a box plot:
#
# * Minimum
# * First quartile (25%) aka Q1
# * Median aka Q2
# * Third quartile (75%) aka Q3
# * Maximum
#
# Here we have `Lower fence` aka Q1 and `Higher fence` aka Q3
#
# suppose we have data: x = 1, 3, 4, 6, 7, 7, 8, 8, 10, 12, 17. Now we know IQR = Q3 - Q1, percentile is the value whose percentile value we are going to find.
#
# $ Percentile = \frac{number\ of\ values\ below\ x}{total\ no.\ of\ values}\ * \ 100 $
#
# $ Q1 = \frac{Percentile}{100}\ * \left ( total\ no.\ of\ values\ + 1 \right ) $ = 4
#
# $ Q3 = \frac{Percentile}{100}\ * \left ( total\ no.\ of\ values\ + 1 \right ) $ = 10
#
# IQR = Q3 - Q1 = 6
#
# * Lower fence = Q1 - 1.5 * IQR = -5
# * Higher fence = Q3 + 1.5 * IQR = 19
#
# If the lower whisker is longer than the upper whisker, the distribution is negatively skewed. The length of the whiskers also gives you information about how spread out the data is. A box-and-whisker plot is often used when the number of data values is large.

# %% [markdown]
# ## 10. Make brief notes on any two of the following:
#
#               1. Data collected at regular intervals
#
#                2. The gap between the quartiles
#
#                3. Use a cross-tab

# %% [markdown]
# ### **Data collected at regular intervals:**
#
# Time series data is a collection of observations obtained through repeated measurements over time. Plot the points on a graph, and one of your axes would always be time.
#
# Time series metrics refer to a piece of data that is tracked at an increment in time. For instance, a metric could refer to how much inventory was sold in a store from one day to the next.
#
# Time series data is everywhere, since time is a constituent of everything that is observable. As our world gets increasingly instrumented, sensors and systems are constantly emitting a relentless stream of time series data. Such data has numerous applications across various industries. Let’s put this in context through some examples.
#
# Examples of time series analysis:
#
# * Electrical activity in the brain
# * Rainfall measurements
# * Stock prices
# * Number of sunspots
# * Annual retail sales
# * Monthly subscribers
# * Heartbeats per minute
#
# ### **Use a Cross tab:**
#
# To describe the relationship between two categorical variables, we use a special type of table called a cross-tabulation (or "crosstab" for short). In a cross-tabulation, the categories of one variable determine the rows of the table, and the categories of the other variable determine the columns. This type of table is also known as a:
#
#     * Crosstab.
#     * Two-way table.
#     * Contingency table.
#
# In pandas we can use pandas.crosstab()
#
# **Example:**
#
# ![cross tab](https://lgimages.s3.amazonaws.com/data/imagemanager/68594/spss_crosstabs_genderalcohol_opt.png)

# %% [markdown]
# ## 11. Make a comparison between:
#
# 1. Data with nominal and ordinal values
#
# 2. Histogram and box plot
#
# 3. The average and median

# %% [markdown]
# ### **Data with nominal and ordinal values:**
#
# First of all both nominal and ordinal values are part of the categorical data in which:
#     * Nominal data in which order does not matter like Male and Female, Boy and Girl. The order does not matter.
#     * Ordinal data in which order matters like Good, Better and Best
#
# ### **Histogram and box plot:**
#
# A histogram is a way to visualize a frequency table, with bins on the x-axis and the data count on the y-axis. Pandas supports histograms for data frames with the DataFrame.plot.hist method. The various plot methods return an axis object that allows further fine-tuning of the visualization using Matplotlib. In general, histograms are plotted such that:
#
# * Empty bins are included in the graph
# * Bins are of equal width
# * The number of bins (or, equivalently, bin size) is up to the user.
# * Bars are contiguous - no empty space shows between bars, unless there is an empty bin.
#
# In Box-plot we have the Quartile ranges and the spread of the data. Both can show outliers, but boxplot is better for them. By having lower and upper whiskers, we can properly manage the data outliers.
#
#
# ### **The average and median:**
#
# The average is the mean of the data, we can use these methods for plotting data on the plots and also for filling the missing values. Average is better for doing operations on data when it is normally distributed and there are no outliers, otherwise it can create chaos, then for the outliers part median is the better choice.
